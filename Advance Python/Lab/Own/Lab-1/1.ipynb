# %%
import pandas as pd

# %%
df = pd.read_csv("meta.csv")
print(df.head())    
print(df.columns)
# Out:
#                Dataset                              Files
# 0       airline-safety  airline-safety/airline-safety.csv
# 1  alcohol-consumption     alcohol-consumption/drinks.csv
# 2             avengers              avengers/avengers.csv
# 3          bad-drivers        bad-drivers/bad-drivers.csv
# 4              bechdel                 bechdel/movies.csv
# Index(['Dataset', 'Files'], dtype='object')

# %%
# for row in df:
#     print(row)

# %%
# print(df.to_string)

# %%
pd.set_option("display.max_rows", None)
df = pd.read_csv("meta.csv")

print(df)
# Out:
#                                 Dataset  \
# 0                        airline-safety
# 1                   alcohol-consumption
# 2                              avengers
# 3                           bad-drivers
# 4                               bechdel
# 5                               biopics
# 6                                births
# 7                                births
# 8                              bob-ross
# 9                              bob-ross
# 10                     buster-posey-mvp
# 11                         classic-rock
# 12                         classic-rock
# 13                         classic-rock
# 14                         classic-rock
# 15                         classic-rock
# 16                       college-majors
# 17                       college-majors
# 18                       college-majors
# 19                       college-majors
# 20                       college-majors
# 21                     comic-characters
# ...
